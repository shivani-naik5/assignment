# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('F:\datasets\crime_data.csv')
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
sns.pairplot(df)

# %%
x=df.drop(columns='Unnamed: 0',axis=1)

# %%
x.head()
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
x=pd.DataFrame(x)

# %%
from scipy.cluster import hierarchy   #linkage dendrogram

# %%
lk=hierarchy.linkage(x,method='complete')
dedo=hierarchy.dendrogram(lk)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ag=AgglomerativeClustering(n_clusters=4)
y=ag.fit_predict(x)
y
# Out:
# array([3, 1, 1, 0, 1, 1, 0, 0, 1, 3, 0, 2, 1, 0, 2, 0, 0, 3, 2, 1, 0, 1,
#        2, 3, 0, 2, 2, 1, 2, 0, 1, 1, 3, 2, 0, 0, 0, 0, 0, 3, 2, 3, 1, 0,
#        2, 0, 0, 2, 2, 0], dtype=int64)

# %%
df['cluster']=y
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape  cluster
# 0     Alabama    13.2      236        58  21.2        3
# 1      Alaska    10.0      263        48  44.5        1
# 2     Arizona     8.1      294        80  31.0        1
# 3    Arkansas     8.8      190        50  19.5        0
# 4  California     9.0      276        91  40.6        1

# %%
df.groupby(by='cluster').mean()
# Out:
#             Murder     Assault   UrbanPop       Rape
# cluster
# 0         6.210526  142.052632  71.263158  19.184211
# 1        10.966667  264.000000  76.500000  33.608333
# 2         3.091667   76.000000  52.083333  11.833333
# 3        14.671429  251.285714  54.285714  21.685714

# %%
sns.scatterplot(df['Murder'],df['UrbanPop'],hue=df['cluster'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Murder', ylabel='UrbanPop'>

# %%
y
# Out:
# array([3, 1, 1, 0, 1, 1, 0, 0, 1, 3, 0, 2, 1, 0, 2, 0, 0, 3, 2, 1, 0, 1,
#        2, 3, 0, 2, 2, 1, 2, 0, 1, 1, 3, 2, 0, 0, 0, 0, 0, 3, 2, 3, 1, 0,
#        2, 0, 0, 2, 2, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.75,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()
lg.fit(xtrain,ytrain)
ypred=lg.predict(xtest)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         4
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         4
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.77        13
#    macro avg       0.75      0.59      0.65        13
# weighted avg       1.00      0.77      0.86        13

# %% [markdown]
# #n_cluster =2  accuracy=0.92
# #n_cluster =4  accuracy=0.77

# %% [markdown]
# # k-Means

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans()

# %%
y=km.fit_predict(x)
y
# Out:
# array([6, 7, 0, 2, 0, 0, 1, 5, 0, 6, 1, 3, 0, 5, 3, 5, 2, 6, 3, 0, 1, 0,
#        5, 4, 0, 2, 5, 0, 3, 1, 0, 0, 4, 3, 5, 5, 5, 5, 1, 4, 3, 6, 0, 1,
#        3, 5, 5, 3, 3, 2])

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(x,y)
# Out:
# 0.24593037443623966

# %%
wcss=[]

for i in range(2,20):
    km=KMeans(n_clusters=i)
    km.fit_predict(x)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [104.96163315756871,
#  79.95548163171662,
#  57.66757825000804,
#  50.33327385184907,
#  44.347436433806834,
#  40.15294703458302,
#  35.90730364626671,
#  30.895266704266405,
#  26.881541874962842,
#  25.20741975046078,
#  22.34046241598852,
#  20.894951931994825,
#  19.428035948876666,
#  18.197966682136396,
#  16.734110071153054,
#  15.233422153794436,
#  14.941155599422894,
#  13.341737947642962]

# %%
plt.plot(range(2,20),wcss)

# %%
km=KMeans(n_clusters=10)
y=km.fit_predict(x)
y
# Out:
# array([7, 9, 4, 6, 1, 1, 0, 5, 8, 7, 0, 3, 4, 6, 3, 6, 6, 7, 3, 8, 5, 8,
#        0, 2, 6, 6, 0, 1, 3, 5, 8, 4, 2, 3, 6, 6, 6, 0, 5, 2, 3, 7, 4, 5,
#        3, 6, 6, 3, 0, 6])

# %%
silhouette_score(x,y)
# Out:
# 0.2626569822734301

# %%
df['kcluster']=y

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df.groupby('kcluster').agg('mean')
# Out:
#              Murder     Assault   UrbanPop       Rape   cluster
# kcluster
# 0          4.083333   81.500000  71.000000  14.733333  1.000000
# 1          9.700000  244.000000  83.333333  41.766667  1.000000
# 2         14.500000  291.666667  45.666667  18.566667  3.000000
# 3          2.687500   72.000000  47.250000  10.425000  2.000000
# 4         10.575000  249.500000  82.250000  26.650000  1.000000
# 5          4.860000  168.000000  82.600000  16.420000  0.000000
# 6          7.066667  142.166667  63.500000  21.050000  0.166667
# 7         14.800000  221.000000  60.750000  24.025000  3.000000
# 8         12.550000  293.750000  72.750000  31.725000  1.000000
# 9         10.000000  263.000000  48.000000  44.500000  1.000000

# %%
df
# Out:
#     Murder  Assault  UrbanPop  Rape  cluster  kcluster
# 0     13.2      236        58  21.2        3         7
# 1     10.0      263        48  44.5        1         9
# 2      8.1      294        80  31.0        1         4
# 3      8.8      190        50  19.5        0         6
# 4      9.0      276        91  40.6        1         1
# 5      7.9      204        78  38.7        1         1
# 6      3.3      110        77  11.1        0         0
# 7      5.9      238        72  15.8        0         5
# 8     15.4      335        80  31.9        1         8
# 9     17.4      211        60  25.8        3         7
# 10     5.3       46        83  20.2        0         0
# 11     2.6      120        54  14.2        2         3
# 12    10.4      249        83  24.0        1         4
# 13     7.2      113        65  21.0        0         6
# 14     2.2       56        57  11.3        2         3
# 15     6.0      115        66  18.0        0         6
# 16     9.7      109        52  16.3        0         6
# 17    15.4      249        66  22.2        3         7
# 18     2.1       83        51   7.8        2         3
# 19    11.3      300        67  27.8        1         8
# 20     4.4      149        85  16.3        0         5
# 21    12.1      255        74  35.1        1         8
# 22     2.7       72        66  14.9        2         0
# 23    16.1      259        44  17.1        3         2
# 24     9.0      178        70  28.2        0         6
# 25     6.0      109        53  16.4        2         6
# 26     4.3      102        62  16.5        2         0
# 27    12.2      252        81  46.0        1         1
# 28     2.1       57        56   9.5        2         3
# 29     7.4      159        89  18.8        0         5
# 30    11.4      285        70  32.1        1         8
# 31    11.1      254        86  26.1        1         4
# 32    13.0      337        45  16.1        3         2
# 33     0.8       45        44   7.3        2         3
# 34     7.3      120        75  21.4        0         6
# 35     6.6      151        68  20.0        0         6
# 36     4.9      159        67  29.3        0         6
# 37     6.3      106        72  14.9        0         0
# 38     3.4      174        87   8.3        0         5
# 39    14.4      279        48  22.5        3         2
# 40     3.8       86        45  12.8        2         3
# 41    13.2      188        59  26.9        3         7
# 42    12.7      201        80  25.5        1         4
# 43     3.2      120        80  22.9        0         5
# 44     2.2       48        32  11.2        2         3
# 45     8.5      156        63  20.7        0         6
# 46     4.0      145        73  26.2        0         6
# 47     5.7       81        39   9.3        2         3
# 48     2.6       53        66  10.8        2         0
# 49     6.8      161        60  15.6        0         6

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=1,min_samples=5)
ydb=db.fit_predict(x)

# %%
silhouette_score(x,ydb)
# Out:
# 0.19486631995858555

# %% [markdown]
#  Selecting Min_samples:
# Number of columns + 1
# Number of columns * 2              ++==4*2=8
# Number of Dimension + 1
# Always keep min_sample at least 3.

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nigh=NearestNeighbors(n_neighbors=8).fit(x)

# %%
d,i=nigh.kneighbors(x)
d
# Out:
# array([[0.        , 0.78006247, 0.84928467, 0.92509451, 1.14292205,
#         1.29621831, 1.30273924, 1.30290503],
#        [0.        , 2.07898369, 2.13697134, 2.30088403, 2.35013877,
#         2.35997304, 2.36811895, 2.56180471],
#        [0.        , 1.0482199 , 1.08341076, 1.09354181, 1.20621365,
#         1.22403776, 1.32378897, 1.37888923],
#        [0.        , 1.0013278 , 1.00722663, 1.07057017, 1.24148411,
#         1.30290503, 1.436899  , 1.43992053],
#        [0.        , 1.20897691, 1.30069114, 1.32378897, 1.53005165,
#         1.6957501 , 1.81930503, 1.93115604],
#        [0.        , 1.24886253, 1.30069114, 1.32606825, 1.37888923,
#         1.41306145, 1.54876384, 1.56244725],
#        [0.        , 0.88100359, 0.95643249, 0.99437327, 1.04597225,
#         1.08653166, 1.22399673, 1.24051012],
#        [0.        , 1.19227586, 1.27140067, 1.42312615, 1.45285466,
#         1.56683387, 1.57429436, 1.59692174],
#        [0.        , 1.30974334, 1.34926273, 1.45009454, 1.5890679 ,
#         1.76715363, 1.77076481, 1.78916837],
#        [0.        , 0.86797806, 1.02250187, 1.14292205, 1.41119063,
#         1.59892947, 1.77539959, 1.85753835],
#        [0.        , 1.08184506, 1.16110091, 1.22422969, 1.34114677,
#         1.39838355, 1.47974886, 1.48228265],
#        [0.        , 0.75913104, 0.81522244, 0.83710697, 0.85722678,
#         0.86721211, 0.93434692, 1.02277299],
#        [0.        , 0.35377437, 0.83250223, 1.09354181, 1.35292516,
#         1.35663452, 1.36905703, 1.410081  ],
#        [0.        , 0.43312429, 0.53571007, 0.61894533, 0.70471473,
#         0.84983119, 0.86574406, 0.89891283],
#        [0.        , 0.2079438 , 0.63822131, 0.65227142, 0.77219944,
#         0.86721211, 0.99215359, 0.9987081 ],
#        [0.        , 0.43312429, 0.52515083, 0.53326883, 0.55122406,
#         0.7665773 , 0.78963622, 0.8436743 ],
#        [0.        , 0.8610239 , 1.07057017, 1.0802983 , 1.10294758,
#         1.19102564, 1.31523679, 1.43637925],
#        [0.        , 0.78006247, 0.86797806, 1.1413243 , 1.28684713,
#         1.32854329, 1.34605704, 1.50630472],
#        [0.        , 0.50466926, 0.65227142, 0.73797792, 0.78923123,
#         0.85722678, 1.160244  , 1.19381036],
#        [0.        , 0.54082482, 1.09106451, 1.22403776, 1.28684713,
#         1.30273924, 1.35663452, 1.45009454],
#        [0.        , 0.80586349, 0.91073424, 0.95367898, 0.95643249,
#         1.14529915, 1.16854043, 1.34114677],
#        [0.        , 0.58411812, 1.09106451, 1.20621365, 1.24886253,
#         1.27374348, 1.30194732, 1.3028395 ],
#        [0.        , 0.49909939, 0.61451768, 0.77219944, 0.93734554,
#         0.98448177, 0.99437327, 1.02092207],
#        [0.        , 0.79455301, 1.1946964 , 1.29621831, 1.59892947,
#         1.64340497, 1.84550521, 1.95147647],
#        [0.        , 0.98866758, 1.00754343, 1.10385973, 1.14424271,
#         1.17724905, 1.23278316, 1.25399065],
#        [0.        , 0.74649625, 0.82328154, 0.83710697, 0.8610239 ,
#         0.89470711, 0.92635696, 1.01352957],
#        [0.        , 0.53326883, 0.61451768, 0.74649625, 0.75913104,
#         0.85691828, 0.86574406, 0.93622983],
#        [0.        , 1.20897691, 1.27374348, 1.41306145, 1.74098162,
#         1.94558328, 1.9698367 , 2.18941957],
#        [0.        , 0.2079438 , 0.50466926, 0.72282762, 0.93256216,
#         0.93434692, 0.93734554, 0.99748634],
#        [0.        , 0.80586349, 1.12125146, 1.32752663, 1.43603876,
#         1.47106244, 1.48172991, 1.48605393],
#        [0.        , 0.54082482, 0.58411812, 1.0482199 , 1.30974334,
#         1.34593691, 1.35292516, 1.45646227],
#        [0.        , 0.35377437, 0.85435645, 1.08341076, 1.3028395 ,
#         1.34593691, 1.45079821, 1.54399433],
#        [0.        , 1.0582674 , 1.1946964 , 1.62065461, 2.00703347,
#         2.07509127, 2.09282778, 2.35883818],
#        [0.        , 0.73797792, 0.93256216, 0.99246041, 1.04297681,
#         1.06413253, 1.28459163, 1.428816  ],
#        [0.        , 0.65497312, 0.70471473, 0.78602982, 0.78963622,
#         0.98237464, 0.98736234, 1.02573141],
#        [0.        , 0.52515083, 0.53571007, 0.57035779, 0.65497312,
#         0.74412537, 0.82632706, 0.96838528],
#        [0.        , 0.59956023, 1.00754343, 1.08430601, 1.190042  ,
#         1.25335755, 1.27930058, 1.29553595],
#        [0.        , 0.55122406, 0.78602982, 0.82632706, 0.84983119,
#         0.85691828, 0.88100359, 1.02092207],
#        [0.        , 0.95367898, 1.08653166, 1.48172991, 1.63952756,
#         1.65354448, 1.77441829, 1.98593431],
#        [0.        , 0.79455301, 0.92509451, 1.0582674 , 1.32854329,
#         1.41119063, 1.45210639, 1.63297034],
#        [0.        , 0.71809843, 0.78923123, 0.81522244, 0.89470711,
#         0.99748634, 0.9987081 , 1.04297681],
#        [0.        , 0.84928467, 1.02250187, 1.1413243 , 1.25399065,
#         1.3651697 , 1.43992053, 1.45210639],
#        [0.        , 0.83250223, 0.85435645, 1.17724905, 1.30194732,
#         1.34605704, 1.45646227, 1.48622129],
#        [0.        , 0.70111326, 0.91073424, 1.02573141, 1.08184506,
#         1.24985321, 1.26562797, 1.28810646],
#        [0.        , 0.99246041, 1.04859428, 1.0966796 , 1.43983912,
#         1.68858387, 1.74740485, 1.79781517],
#        [0.        , 0.57035779, 0.61894533, 0.71097658, 0.8436743 ,
#         0.98736234, 0.98866758, 1.00722663],
#        [0.        , 0.59956023, 0.70111326, 0.96838528, 0.98237464,
#         1.15215431, 1.16966754, 1.26296871],
#        [0.        , 0.71809843, 1.04859428, 1.19381036, 1.28459163,
#         1.28877213, 1.45446212, 1.47976483],
#        [0.        , 0.49909939, 0.63822131, 0.72282762, 0.9818558 ,
#         1.04597225, 1.160244  , 1.22283015],
#        [0.        , 0.71097658, 0.74412537, 0.7665773 , 0.82328154,
#         0.89891283, 0.93622983, 1.0013278 ]])

# %%
dist=np.sort(d[:,1],axis=0)

# %%
dist
# Out:
# array([0.2079438 , 0.2079438 , 0.35377437, 0.35377437, 0.43312429,
#        0.43312429, 0.49909939, 0.49909939, 0.50466926, 0.52515083,
#        0.53326883, 0.54082482, 0.54082482, 0.55122406, 0.57035779,
#        0.58411812, 0.59956023, 0.59956023, 0.65497312, 0.70111326,
#        0.71097658, 0.71809843, 0.71809843, 0.73797792, 0.74649625,
#        0.75913104, 0.78006247, 0.78006247, 0.79455301, 0.79455301,
#        0.80586349, 0.80586349, 0.83250223, 0.84928467, 0.8610239 ,
#        0.86797806, 0.88100359, 0.95367898, 0.98866758, 0.99246041,
#        1.0013278 , 1.0482199 , 1.0582674 , 1.08184506, 1.19227586,
#        1.20897691, 1.20897691, 1.24886253, 1.30974334, 2.07898369])

# %%
plt.plot(dist)

# %%
db=DBSCAN(eps=1.35,min_samples=8)

# %%
ypred=db.fit_predict(x)

# %%
silhouette_score(x,ypred)
# Out:
# 0.24746289589070158

# %%
df['DBcluster']=ypred

# %%
df[df['DBcluster']==-1]        #outlier
# Out:
#     Murder  Assault  UrbanPop  Rape  cluster  kcluster  DBcluster
# 1     10.0      263        48  44.5        1         9         -1
# 4      9.0      276        91  40.6        1         1         -1
# 12    10.4      249        83  24.0        1         4         -1
# 32    13.0      337        45  16.1        3         2         -1

# %%
df.drop(columns=['cluster','kcluster'])
# Out:
#     Murder  Assault  UrbanPop  Rape  DBcluster
# 0     13.2      236        58  21.2          0
# 1     10.0      263        48  44.5         -1
# 2      8.1      294        80  31.0          2
# 3      8.8      190        50  19.5          0
# 4      9.0      276        91  40.6         -1
# 5      7.9      204        78  38.7          1
# 6      3.3      110        77  11.1          1
# 7      5.9      238        72  15.8          1
# 8     15.4      335        80  31.9          2
# 9     17.4      211        60  25.8          0
# 10     5.3       46        83  20.2          1
# 11     2.6      120        54  14.2          1
# 12    10.4      249        83  24.0         -1
# 13     7.2      113        65  21.0          1
# 14     2.2       56        57  11.3          1
# 15     6.0      115        66  18.0          1
# 16     9.7      109        52  16.3          1
# 17    15.4      249        66  22.2          0
# 18     2.1       83        51   7.8          1
# 19    11.3      300        67  27.8          0
# 20     4.4      149        85  16.3          1
# 21    12.1      255        74  35.1          2
# 22     2.7       72        66  14.9          1
# 23    16.1      259        44  17.1          0
# 24     9.0      178        70  28.2          1
# 25     6.0      109        53  16.4          1
# 26     4.3      102        62  16.5          1
# 27    12.2      252        81  46.0          2
# 28     2.1       57        56   9.5          1
# 29     7.4      159        89  18.8          1
# 30    11.4      285        70  32.1          2
# 31    11.1      254        86  26.1          2
# 32    13.0      337        45  16.1         -1
# 33     0.8       45        44   7.3          1
# 34     7.3      120        75  21.4          1
# 35     6.6      151        68  20.0          1
# 36     4.9      159        67  29.3          1
# 37     6.3      106        72  14.9          1
# 38     3.4      174        87   8.3          1
# 39    14.4      279        48  22.5          0
# 40     3.8       86        45  12.8          1
# 41    13.2      188        59  26.9          0
# 42    12.7      201        80  25.5          1
# 43     3.2      120        80  22.9          1
# 44     2.2       48        32  11.2          1
# 45     8.5      156        63  20.7          1
# 46     4.0      145        73  26.2          1
# 47     5.7       81        39   9.3          1
# 48     2.6       53        66  10.8          1
# 49     6.8      161        60  15.6          1

# %%
sns.pairplot(df,hue='DBcluster',palette='rainbow')

# %%
df['DBcluster'].value_counts()
# Out:
#  1    32
#  0     8
#  2     6
# -1     4
# Name: DBcluster, dtype: int64
